# %% [markdown]
# # About Map Block

# %% [markdown]
# - T-section
#   - Now I can control the type of t-secion by hacking into [here](https://github.com/metadriverse/metadrive/blob/ee5e1f8321ed0423a82c466132970f2dbbbc622a/metadrive/component/pgblock/t_intersection.py#L55) and directly change t_type like `t_type = 1`
#   - So, how to input this t_type externally?

# %% [markdown]
# - Intersection
#   - How to generate an intersection with or without traffic light?
#   - How to generate an intersection and control the ego car's trajectory, such as going straight, left turn, right turn.
